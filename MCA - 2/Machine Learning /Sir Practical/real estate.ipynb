# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
data = pd.read_csv("Real estate.csv")

# %%
data
# Out:
#       No  X1 transaction date  X2 house age  \
# 0      1             2012.917          32.0
# 1      2             2012.917          19.5
# 2      3             2013.583          13.3
# 3      4             2013.500          13.3
# 4      5             2012.833           5.0
# ..   ...                  ...           ...
# 409  410             2013.000          13.7
# 410  411             2012.667           5.6
# 411  412             2013.250          18.8
# 412  413             2013.000           8.1
# 413  414             2013.500           6.5
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                  84.87882                               10
# 1                                 306.59470                                9
# 2                                 561.98450                                5
# 3                                 561.98450                                5
# ...

# %%
data.drop(['No','X1 transaction date'],axis=1,inplace=True)

# %%
data
# Out:
#      X2 house age  X3 distance to the nearest MRT station  \
# 0            32.0                                84.87882
# 1            19.5                               306.59470
# 2            13.3                               561.98450
# 3            13.3                               561.98450
# 4             5.0                               390.56840
# ..            ...                                     ...
# 409          13.7                              4082.01500
# 410           5.6                                90.45606
# 411          18.8                               390.96960
# 412           8.1                               104.81010
# 413           6.5                                90.45606
#
#      X4 number of convenience stores  X5 latitude  X6 longitude  \
# 0                                 10     24.98298     121.54024
# 1                                  9     24.98034     121.53951
# 2                                  5     24.98746     121.54391
# ...

# %%
data
# Out:
#      X2 house age  X3 distance to the nearest MRT station  \
# 0            32.0                                84.87882
# 1            19.5                               306.59470
# 2            13.3                               561.98450
# 3            13.3                               561.98450
# 4             5.0                               390.56840
# ..            ...                                     ...
# 409          13.7                              4082.01500
# 410           5.6                                90.45606
# 411          18.8                               390.96960
# 412           8.1                               104.81010
# 413           6.5                                90.45606
#
#      X4 number of convenience stores  X5 latitude  X6 longitude  \
# 0                                 10     24.98298     121.54024
# 1                                  9     24.98034     121.53951
# 2                                  5     24.98746     121.54391
# ...

# %%
data['X5 latitude'].max()
# Out:
# 25.01459

# %%
data['X5 latitude'].min()
# Out:
# 24.93207

# %%
data['X5 latitude'].max()-data['X5 latitude'].min()
# Out:
# 0.08251999999999882

# %%
data['X6 longitude'].max()-data['X6 longitude'].min()
# Out:
# 0.09274000000000626

# %%
plt.scatter(data['X5 latitude'],data['Y house price of unit area'])

# %%
data[['X5 latitude','Y house price of unit area']].corr()
# Out:
#                             X5 latitude  Y house price of unit area
# X5 latitude                    1.000000                    0.546307
# Y house price of unit area     0.546307                    1.000000

# %%
data[['X6 longitude','Y house price of unit area']].corr()
# Out:
#                             X6 longitude  Y house price of unit area
# X6 longitude                    1.000000                    0.523287
# Y house price of unit area      0.523287                    1.000000

# %%
data.corr()
# Out:
#                                         X2 house age  \
# X2 house age                                1.000000
# X3 distance to the nearest MRT station      0.025622
# X4 number of convenience stores             0.049593
# X5 latitude                                 0.054420
# X6 longitude                               -0.048520
# Y house price of unit area                 -0.210567
#
#                                         X3 distance to the nearest MRT station  \
# X2 house age                                                          0.025622
# X3 distance to the nearest MRT station                                1.000000
# X4 number of convenience stores                                      -0.602519
# X5 latitude                                                          -0.591067
# X6 longitude                                                         -0.806317
# Y house price of unit area                                           -0.673613
#
# ...

# %%
upper=data['Y house price of unit area'].quantile(0.75)
lower=data['Y house price of unit area'].quantile(0.25)
IQR=upper-lower
IQR*1.5
# Out:
# 27.900000000000002

# %%
sns.boxplot(data['Y house price of unit area'])
# Out:
# C:\Users\majum\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Y house price of unit area'>

# %%
plt.hist(data['Y house price of unit area'])
plt.show()

# %%
data['X2 house age','X3 distance to the nearest MRT station']

# %%
plt.scatter(data['X3 distance to the nearest MRT station'],data['Y house price of unit area'])

# %%
data[(data['Y house price of unit area']>10) & (data['Y house price of unit area']<70)]
# Out:
#      X2 house age  X3 distance to the nearest MRT station  \
# 0            32.0                                84.87882
# 1            19.5                               306.59470
# 2            13.3                               561.98450
# 3            13.3                               561.98450
# 4             5.0                               390.56840
# ..            ...                                     ...
# 409          13.7                              4082.01500
# 410           5.6                                90.45606
# 411          18.8                               390.96960
# 412           8.1                               104.81010
# 413           6.5                                90.45606
#
#      X4 number of convenience stores  X5 latitude  X6 longitude  \
# 0                                 10     24.98298     121.54024
# 1                                  9     24.98034     121.53951
# 2                                  5     24.98746     121.54391
# ...

# %%
data.drop(index=data[(data['Y house price of unit area']<10) | (data['Y house price of unit area']>70)].index,axis=0,inplace=True)

# %%
data
# Out:
#      X2 house age  X3 distance to the nearest MRT station  \
# 0            32.0                                84.87882
# 1            19.5                               306.59470
# 2            13.3                               561.98450
# 3            13.3                               561.98450
# 4             5.0                               390.56840
# ..            ...                                     ...
# 409          13.7                              4082.01500
# 410           5.6                                90.45606
# 411          18.8                               390.96960
# 412           8.1                               104.81010
# 413           6.5                                90.45606
#
#      X4 number of convenience stores  X5 latitude  X6 longitude  \
# 0                                 10     24.98298     121.54024
# 1                                  9     24.98034     121.53951
# 2                                  5     24.98746     121.54391
# ...

# %%
sns.boxplot(data['Y house price of unit area'])
# Out:
# C:\Users\majum\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Y house price of unit area'>

# %%
X= data[['X2 house age','X3 distance to the nearest MRT station']]
Y= data['Y house price of unit area']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.30, random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
lr.intercept_
# Out:
# 47.81129980767851

# %%
lr.coef_
# Out:
# array([-0.1807217 , -0.00708733])

# %%
y_pred = lr.predict(X_test)

# %%
pd.DataFrame({'Actual':y_test,'Predicted':y_pred})
# Out:
#      Actual  Predicted
# 71     40.8  36.854551
# 223    42.3  36.230184
# 263    31.7  31.887325
# 34     55.1  43.572682
# 43     34.1  37.960182
# ..      ...        ...
# 61     63.2  45.013174
# 80     40.3  41.897862
# 296    34.1  37.441284
# 232    17.4  11.639024
# 311    42.2  40.150383
#
# [123 rows x 2 columns]

# %%
from sklearn.metrics import r2_score,mean_squared_error

# %%
print(r2_score(y_test,y_pred))
# Out:
# 0.5459080610646392

# %%
import numpy as np
print((mean_squared_error(y_test,y_pred)**0.5))
# Out:
# 8.758087061504845

# %%
plt.scatter(X_test['X3 distance to the nearest MRT station'],y_test)

# %%
sns.pairplot(data)

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
plr = PolynomialFeatures(degree=)
